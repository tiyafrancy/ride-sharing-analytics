# %% [markdown]
# # Data Model Implementation

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# import tensorflow as tf

# %%
import pandas as pd
import sqlalchemy

# %%
# Connect to SQL database
engine = sqlalchemy.create_engine('sqlite:////content/ride_share.db')
query = "SELECT * FROM ride_share_table"
df = pd.read_sql(query, engine)

# %%
df.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0003               B03404               B03404
#
#       request_datetime    on_scene_datetime      pickup_datetime  \
# 0  2025-03-03 08:50:50  2025-03-03 08:51:10  2025-03-03 08:53:11
# 1  2025-03-30 10:01:05  2025-03-30 10:04:45  2025-03-30 10:05:02
# 2  2025-03-15 08:10:41  2025-03-15 08:14:21  2025-03-15 08:16:22
# 3  2025-03-01 05:42:30  2025-03-01 05:55:15  2025-03-01 05:56:45
# 4  2025-03-09 01:51:57  2025-03-09 01:54:59  2025-03-09 01:57:01
#
#       dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  \
# 0  2025-03-03 09:04:35           161           162        0.57  ...
# 1  2025-03-30 10:17:03            61            37        2.14  ...
# 2  2025-03-15 08:20:29           200           220        0.92  ...
# 3  2025-03-01 06:38:43           249           177        7.57  ...
# 4  2025-03-09 03:15:13           157            61        3.77  ...
#
#    airport_fee  tips  driver_pay  shared_request_flag  shared_match_flag  \
# 0          0.0   0.0        7.70                    N                  N
# 1          0.0   0.0       14.55                    N                  N
# 2          0.0   0.0        6.00                    N                  N
# 3          0.0   0.0       40.38                    N                  N
# 4          0.0   0.0       16.35                    N                  N
#
#    access_a_ride_flag  wav_request_flag  wav_match_flag  cbd_congestion_fee  \
# 0                   N                 N               N                 1.5
# 1                   N                 N               N                 0.0
# 2                   N                 N               Y                 0.0
# 3                   N                 N               N                 1.5
# 4                   N                 N               N                 0.0
#
#   weather_condition
# 0             Clear
# 1            Cloudy
# 2          Overcast
# 3            Cloudy
# 4             Clear
#
# [5 rows x 26 columns]

# %%
# Drop the non-beneficial columns
columns_to_drop = ["hvfhs_license_num", "dispatching_base_num", "originating_base_num", "request_datetime",
    "on_scene_datetime", "pickup_datetime", "dropoff_datetime",
    "shared_request_flag", "shared_match_flag", "access_a_ride_flag",
    "wav_request_flag", "wav_match_flag", "tolls", "bcf", "sales_tax",
    "congestion_surcharge", "airport_fee"]
df = df.drop(columns = columns_to_drop, axis = 1)

# %%
df.head()
# Out:
#    PULocationID  DOLocationID  trip_miles  trip_time  base_passenger_fare  \
# 0           161           162        0.57        685                14.97
# 1            61            37        2.14        721                25.07
# 2           200           220        0.92        247                 9.59
# 3           249           177        7.57       2518                40.87
# 4           157            61        3.77       1092                27.29
#
#    tips  driver_pay  cbd_congestion_fee weather_condition
# 0   0.0        7.70                 1.5             Clear
# 1   0.0       14.55                 0.0            Cloudy
# 2   0.0        6.00                 0.0          Overcast
# 3   0.0       40.38                 1.5            Cloudy
# 4   0.0       16.35                 0.0             Clear

# %%
df.nunique()
# Out:
# PULocationID            253
# DOLocationID            256
# trip_miles             7367
# trip_time              3240
# base_passenger_fare    5694
# tips                   1088
# driver_pay             4918
# cbd_congestion_fee        2
# weather_condition        10
# dtype: int64

# %%
# looking at PULocationID value counts to identify and replace with "Others"
pulocationid_count = df["PULocationID"].value_counts()
pulocationid_count
# Out:
# PULocationID
# 138    429
# 132    357
# 79     269
# 61     264
# 230    247
#       ...
# 12       2
# 27       1
# 253      1
# 96       1
# 8        1
# Name: count, Length: 253, dtype: int64

# %%
# Choose a cutoff value to be replaced
pulocationid_to_replace = list(pulocationid_count[pulocationid_count < 20].index)

for loc in pulocationid_to_replace:
  df["PULocationID"] = df["PULocationID"].replace(loc, "Others")

# Check to make sure replacement was successful
df["PULocationID"].value_counts()
# Out:
# PULocationID
# 138       429
# Others    412
# 132       357
# 79        269
# 61        264
#          ...
# 131        22
# 252        22
# 73         22
# 98         21
# 115        20
# Name: count, Length: 208, dtype: int64

# %%
# looking at DOLocationID value counts to identify and replace with "Others"
dolocationid_count = df["DOLocationID"].value_counts()
dolocationid_count
# Out:
# DOLocationID
# 265    882
# 132    445
# 138    397
# 61     294
# 37     241
#       ...
# 30       1
# 5        1
# 154      1
# 184      1
# 12       1
# Name: count, Length: 256, dtype: int64

# %%
# Choose a cutoff value to be replaced
dolocationid_to_replace = list(dolocationid_count[dolocationid_count < 20].index)

for loc in dolocationid_to_replace:
  df["DOLocationID"] = df["DOLocationID"].replace(loc, "Others")

# Check to make sure replacement was successful
df["DOLocationID"].value_counts()
# Out:
# DOLocationID
# 265       882
# Others    464
# 132       445
# 138       397
# 61        294
#          ...
# 34         23
# 252        22
# 221        21
# 192        20
# 23         20
# Name: count, Length: 207, dtype: int64

# %%
# looking at weather_condition value counts to identify and replace with "Others"
weather_condition_count = df["weather_condition"].value_counts()
weather_condition_count
# Out:
# weather_condition
# Cloudy               9010
# Clear                6015
# Fair                 1980
# Overcast             1355
# Heavy Rain            476
# Light Rain            421
# Rain                  375
# Fog                   211
# Rain Shower            95
# Heavy Rain Shower      62
# Name: count, dtype: int64

# %%
# Handle categorical variables (e.g., PULocationID, DOLocationID, weather condition)
df = pd.get_dummies(df, columns=["PULocationID", "DOLocationID", "weather_condition"])

# %%
# Define features and target variable
y = df["driver_pay"]
X = df.drop("driver_pay", axis=1)

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train and Evaluate the Model

# %%
# from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import r2_score

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
num_input_features =  len(X_train_scaled[1])
hidden_nodes_layer1 = 64
hidden_nodes_layer2 = 32

model = Sequential()

# First hidden layer
model.add(Dense(units = hidden_nodes_layer1, input_dim = num_input_features, activation = "relu"))

# Second hidden layer
model.add(Dense(units = hidden_nodes_layer2, activation = "relu"))

# Output layer
# model.add(Dense(units = 1, activation = "sigmoid"))

model.add(Dense(units = 1))

# Check the structure of the model
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_19 (Dense)                │ (None, 64)             │        27,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,697 (116.00 KB)
#  Trainable params: 29,697 (116.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["mae"])

# %%
model_fitted = model.fit(X_train_scaled, y_train, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 360.5024 - mae: 12.7554 - val_loss: 37.9393 - val_mae: 4.5283
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29.1631 - mae: 3.7328 - val_loss: 20.8441 - val_mae: 2.9580
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.9829 - mae: 2.4326 - val_loss: 18.1450 - val_mae: 2.6315
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 12.4717 - mae: 2.1272 - val_loss: 17.1708 - val_mae: 2.5453
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.9807 - mae: 1.9709 - val_loss: 17.0075 - val_mae: 2.4918
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 10.6873 - mae: 1.9401 - val_loss: 16.8708 - val_mae: 2.4705
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.7090 - mae: 1.8481 - val_loss: 17.3164 - val_mae: 2.5691
# Epoch 8/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.8609 - mae: 1.8671 - val_loss: 17.1539 - val_mae: 2.4945
# Epoch 9/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5522 - mae: 1.8167 - val_loss: 17.3509 - val_mae: 2.5247
# Epoch 10/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 8.7341 - mae: 1.7354 - val_loss: 16.6424 - val_mae: 2.4781
# Epoch 11/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 8.1530 - mae: 1.7275 - val_loss: 18.4844 - val_mae: 2.5764
# Epoch 12/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.7527 - mae: 1.6962 - val_loss: 17.3652 - val_mae: 2.6167
# Epoch 13/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.2251 - mae: 1.7296 - val_loss: 17.0689 - val_mae: 2.5320
# Epoch 14/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.2832 - mae: 1.6583 - val_loss: 19.6786 - val_mae: 2.6849
# Epoch 15/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 8.1295 - mae: 1.7329 - val_loss: 17.8841 - val_mae: 2.5865
# Epoch 16/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 8.0546 - mae: 1.6922 - val_loss: 17.8385 - val_mae: 2.6194
# Epoch 17/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.5529 - mae: 1.6224 - val_loss: 17.2670 - val_mae: 2.5452
# Epoch 18/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.8765 - mae: 1.6323 - val_loss: 17.2761 - val_mae: 2.5798
# Epoch 19/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.7094 - mae: 1.5212 - val_loss: 18.2308 - val_mae: 2.6481
# Epoch 20/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.6836 - mae: 1.5573 - val_loss: 18.9198 - val_mae: 2.6595
# Epoch 21/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7297 - mae: 1.5484 - val_loss: 18.6986 - val_mae: 2.6359
# Epoch 22/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 6.6240 - mae: 1.5109 - val_loss: 18.3201 - val_mae: 2.6499
# Epoch 23/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.5467 - mae: 1.5393 - val_loss: 18.1324 - val_mae: 2.6142
# Epoch 24/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.4984 - mae: 1.4744 - val_loss: 17.4897 - val_mae: 2.6332
# Epoch 25/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.2314 - mae: 1.4597 - val_loss: 18.3785 - val_mae: 2.6383
# Epoch 26/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.1871 - mae: 1.4290 - val_loss: 17.7760 - val_mae: 2.5911
# Epoch 27/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6.2731 - mae: 1.4499 - val_loss: 19.0411 - val_mae: 2.6805
# Epoch 28/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.8783 - mae: 1.4260 - val_loss: 17.9592 - val_mae: 2.6465
# Epoch 29/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.0292 - mae: 1.4292 - val_loss: 18.3174 - val_mae: 2.7511
# Epoch 30/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5.8821 - mae: 1.4564 - val_loss: 19.6106 - val_mae: 2.6971
# Epoch 31/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.7375 - mae: 1.4521 - val_loss: 19.2876 - val_mae: 2.7352
# Epoch 32/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.7303 - mae: 1.4251 - val_loss: 17.8996 - val_mae: 2.6275
# Epoch 33/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0439 - mae: 1.4315 - val_loss: 19.3761 - val_mae: 2.7094
# Epoch 34/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6.0400 - mae: 1.4081 - val_loss: 17.9132 - val_mae: 2.6424
# Epoch 35/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 5.2254 - mae: 1.3371 - val_loss: 18.6537 - val_mae: 2.6752
# Epoch 36/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.1201 - mae: 1.3974 - val_loss: 17.5565 - val_mae: 2.6006
# Epoch 37/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5.4485 - mae: 1.3114 - val_loss: 17.8173 - val_mae: 2.6708
# Epoch 38/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5.5412 - mae: 1.3396 - val_loss: 20.7469 - val_mae: 2.8187
# Epoch 39/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.4877 - mae: 1.2741 - val_loss: 18.2107 - val_mae: 2.7097
# Epoch 40/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.7459 - mae: 1.3054 - val_loss: 18.5193 - val_mae: 2.6787
# Epoch 41/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.7410 - mae: 1.2884 - val_loss: 18.7176 - val_mae: 2.7709
# Epoch 42/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5067 - mae: 1.2790 - val_loss: 18.3255 - val_mae: 2.7375
# Epoch 43/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.7597 - mae: 1.2786 - val_loss: 18.1406 - val_mae: 2.6783
# Epoch 44/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.0694 - mae: 1.2603 - val_loss: 18.4527 - val_mae: 2.6986
# Epoch 45/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.5579 - mae: 1.2545 - val_loss: 18.9978 - val_mae: 2.7138
# Epoch 46/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4922 - mae: 1.2446 - val_loss: 18.1686 - val_mae: 2.6904
# Epoch 47/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.0187 - mae: 1.2398 - val_loss: 18.1333 - val_mae: 2.7470
# Epoch 48/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 4.0789 - mae: 1.2086 - val_loss: 18.8309 - val_mae: 2.7310
# Epoch 49/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.1976 - mae: 1.2518 - val_loss: 18.7331 - val_mae: 2.7418
# Epoch 50/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.6430 - mae: 1.2669 - val_loss: 18.4050 - val_mae: 2.7269
# Epoch 51/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.1500 - mae: 1.2590 - val_loss: 18.7534 - val_mae: 2.7362
# Epoch 52/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3.7345 - mae: 1.1794 - val_loss: 21.3677 - val_mae: 2.8560
# Epoch 53/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.9524 - mae: 1.1883 - val_loss: 19.4206 - val_mae: 2.8903
# Epoch 54/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.3706 - mae: 1.2599 - val_loss: 17.9905 - val_mae: 2.7187
# Epoch 55/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.7906 - mae: 1.2083 - val_loss: 18.6449 - val_mae: 2.7596
# Epoch 56/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.9650 - mae: 1.1544 - val_loss: 18.0922 - val_mae: 2.6955
# Epoch 57/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.3085 - mae: 1.0908 - val_loss: 19.3004 - val_mae: 2.8033
# Epoch 58/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9331 - mae: 1.1604 - val_loss: 18.5256 - val_mae: 2.7375
# Epoch 59/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9182 - mae: 1.1214 - val_loss: 18.2028 - val_mae: 2.7194
# Epoch 60/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.1319 - mae: 1.2031 - val_loss: 18.4029 - val_mae: 2.7225
# Epoch 61/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.6154 - mae: 1.1474 - val_loss: 18.8339 - val_mae: 2.7574
# Epoch 62/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.4400 - mae: 1.1005 - val_loss: 20.2170 - val_mae: 2.7865
# Epoch 63/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.9804 - mae: 1.1154 - val_loss: 18.4785 - val_mae: 2.7079
# Epoch 64/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.8851 - mae: 1.1472 - val_loss: 18.7199 - val_mae: 2.7428
# Epoch 65/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3746 - mae: 1.0728 - val_loss: 19.1326 - val_mae: 2.7504
# Epoch 66/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4.1389 - mae: 1.0833 - val_loss: 19.8029 - val_mae: 2.8129
# Epoch 67/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.1828 - mae: 1.0605 - val_loss: 19.1469 - val_mae: 2.7548
# Epoch 68/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.1031 - mae: 1.1175 - val_loss: 21.0332 - val_mae: 2.8654
# Epoch 69/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3.9416 - mae: 1.1377 - val_loss: 18.9929 - val_mae: 2.7554
# Epoch 70/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.2375 - mae: 1.1484 - val_loss: 19.1931 - val_mae: 2.7550
# Epoch 71/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1131 - mae: 1.0390 - val_loss: 19.4345 - val_mae: 2.7744
# Epoch 72/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.2186 - mae: 1.0664 - val_loss: 18.7058 - val_mae: 2.7470
# Epoch 73/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.0299 - mae: 1.0334 - val_loss: 19.4114 - val_mae: 2.8037
# Epoch 74/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.8025 - mae: 1.0139 - val_loss: 19.4029 - val_mae: 2.8076
# Epoch 75/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1172 - mae: 1.0489 - val_loss: 20.6889 - val_mae: 2.8174
# Epoch 76/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.3477 - mae: 1.0240 - val_loss: 19.2375 - val_mae: 2.7923
# Epoch 77/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.1272 - mae: 1.0120 - val_loss: 19.2437 - val_mae: 2.7986
# Epoch 78/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.1887 - mae: 1.0494 - val_loss: 18.8619 - val_mae: 2.7614
# Epoch 79/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.2453 - mae: 1.0646 - val_loss: 19.5600 - val_mae: 2.8153
# Epoch 80/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.5340 - mae: 1.0427 - val_loss: 19.2954 - val_mae: 2.8045
# Epoch 81/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.9038 - mae: 0.9931 - val_loss: 19.2796 - val_mae: 2.7836
# Epoch 82/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6564 - mae: 0.9922 - val_loss: 23.0237 - val_mae: 2.9881
# Epoch 83/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.9957 - mae: 1.0410 - val_loss: 18.9939 - val_mae: 2.7803
# Epoch 84/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3.3135 - mae: 1.0387 - val_loss: 20.8310 - val_mae: 2.8397
# Epoch 85/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.0952 - mae: 1.0174 - val_loss: 20.6452 - val_mae: 2.8698
# Epoch 86/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.2564 - mae: 1.0556 - val_loss: 19.7607 - val_mae: 2.8276
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.1023 - mae: 1.0500 - val_loss: 20.2805 - val_mae: 2.8858
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.1162 - mae: 1.0326 - val_loss: 20.0855 - val_mae: 2.8641
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.9176 - mae: 1.0208 - val_loss: 19.7986 - val_mae: 2.7925
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4517 - mae: 1.0214 - val_loss: 20.0791 - val_mae: 2.8912
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.0371 - mae: 0.9978 - val_loss: 19.3341 - val_mae: 2.8071
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3569 - mae: 0.9181 - val_loss: 22.1443 - val_mae: 2.9224
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.1900 - mae: 1.0308 - val_loss: 20.3084 - val_mae: 2.8233
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.7009 - mae: 1.0077 - val_loss: 19.6390 - val_mae: 2.8249
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.5016 - mae: 0.9329 - val_loss: 21.1236 - val_mae: 2.9172
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2.9531 - mae: 1.0011 - val_loss: 19.5193 - val_mae: 2.8008
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.2583 - mae: 0.9913 - val_loss: 19.7124 - val_mae: 2.7981
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.9932 - mae: 0.9900 - val_loss: 19.4418 - val_mae: 2.7974
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.6426 - mae: 0.9539 - val_loss: 20.0718 - val_mae: 2.8502
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.8746 - mae: 0.9724 - val_loss: 19.3652 - val_mae: 2.7809

# %%
# Make predictions on the test set
y_pred = model.predict(X_test_scaled)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print(f"R-squared: {r_squared:.2f}")
# Out:
# R-squared: 0.94

# %%
# Check if the R-squared meets the threshold
if r_squared >= 0.80:
    print("The model demonstrates meaningful predictive power with at least 0.80 R-squared.")
else:
    print("The model does not meet the 0.80 R-squared threshold.")
# Out:
# The model demonstrates meaningful predictive power with at least 0.80 R-squared.

# %%
# Save the model to a file
model.save("ride_share_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Data Model Optimization

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras_tuner import RandomSearch

# %%
# Function to create the model
def create_model(hp):
    model = Sequential()

    # Choose activation function
    activation = hp.Choice("activation", ["relu", "tanh"])

    # Input layer
    model.add(Dense(
        units=hp.Int("number_of_neurons_layer0", 8, 512, step=32),
        activation=activation,
        input_dim=X_train_scaled.shape[1]  # Number of features
    ))

    # Hidden layers
    for x in range(hp.Int("hidden_layer_number", 1, 6)):  # 1 to 6 hidden layers
        model.add(Dense(
            units=hp.Int(f"number_of_neurons_layer{x}", 8, 512, step=32),
            activation=activation
        ))

    # Output layer
    model.add(Dense(units=1))  # No activation for regression

    # Compile the model
    model.compile(
        loss="mean_squared_error",  # Use mean squared error for regression
        optimizer=Adam(hp.Choice("learning_rate", values=[0.01, 0.001, 0.0001])),
        metrics=["mae"]  # Mean absolute error for regression
    )

    return model

# %%
# Initialize the tuner
tuner = RandomSearch(
    create_model,
    objective="val_mae",  # Use mean absolute error for regression
    max_trials=5,
    project_name="ride_share_model_optimization"
)
# Out:
# Reloading Tuner from ./ride_share_model_optimization/tuner0.json

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True, verbose=1)

# %%
# Search for the best model
tuner.search(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test), callbacks=[early_stopping])

# %%
# Get the best model and evaluate
best_model = tuner.get_best_models(1)[0]
y_pred = best_model.predict(X_test_scaled)
r_squared = r2_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
# Log the results
optimization_results = {
    'Best R-squared': [r_squared],
    'Notes': ['Best model found using hyperparameter tuning']
}

# %%
# Convert results to DataFrame and save to CSV
optimization_df = pd.DataFrame(optimization_results)
optimization_df.to_csv('model_optimization_results.csv', index=False)

# %%
print("Model performance metrics saved to 'model_optimization_results.csv'.")
print(optimization_df)
print(f"Final R-squared value: {r_squared:.2f}")
# Out:
# Model performance metrics saved to 'model_optimization_results.csv'.
#    Best R-squared                                         Notes
# 0        0.948458  Best model found using hyperparameter tuning
# Final R-squared value: 0.95
